# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('laptops.csv')
data
# Out:
#     Company             Product   TypeName  Inches  \
# 0     Apple         MacBook Pro  Ultrabook    13.3
# 1     Apple         Macbook Air  Ultrabook    13.3
# 2        HP              250 G6   Notebook    15.6
# 3     Apple         MacBook Pro  Ultrabook    15.4
# 4     Apple         MacBook Pro  Ultrabook    13.3
# ..      ...                 ...        ...     ...
# 494    Asus    Rog G752VL-UH71T     Gaming    17.3
# 495  Lenovo       Thinkpad X260  Ultrabook    12.5
# 496  Lenovo  Ideapad 520-15IKBR   Notebook    15.6
# 497      HP       EliteBook 840   Notebook    14.0
# 498  Lenovo         ThinkPad 13   Notebook    13.3
#
#                               ScreenResolution                          Cpu  \
# 0           IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz
# 1                                     1440x900         Intel Core i5 1.8GHz
# 2                            Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# ...

# %%
data.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69
# ...

# %%
data.tail()
# Out:
#     Company             Product   TypeName  Inches  \
# 494    Asus    Rog G752VL-UH71T     Gaming    17.3
# 495  Lenovo       Thinkpad X260  Ultrabook    12.5
# 496  Lenovo  Ideapad 520-15IKBR   Notebook    15.6
# 497      HP       EliteBook 840   Notebook    14.0
# 498  Lenovo         ThinkPad 13   Notebook    13.3
#
#                               ScreenResolution                          Cpu  \
# 494  IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i7 6700HQ 2.6GHz
# 495                         IPS Panel 1366x768   Intel Core i5 6200U 2.3GHz
# 496                          Full HD 1920x1080   Intel Core i7 8550U 1.8GHz
# 497                          Full HD 1920x1080   Intel Core i7 7600U 2.8GHz
# 498                IPS Panel Full HD 1920x1080   Intel Core i3 7100U 2.4GHz
#
#       Ram                Memory                      Gpu       OpSys  Weight  \
# 494  24GB  256GB SSD +  1TB HDD  Nvidia GeForce GTX 965M  Windows 10  4.33kg
# ...

# %%
to_drop = ['Inches', 'ScreenResolution', 'Weight']
data.drop(to_drop, inplace=True, axis=1)
data
# Out:
#     Company             Product   TypeName                          Cpu   Ram  \
# 0     Apple         MacBook Pro  Ultrabook         Intel Core i5 2.3GHz   8GB
# 1     Apple         Macbook Air  Ultrabook         Intel Core i5 1.8GHz   8GB
# 2        HP              250 G6   Notebook   Intel Core i5 7200U 2.5GHz   8GB
# 3     Apple         MacBook Pro  Ultrabook         Intel Core i7 2.7GHz  16GB
# 4     Apple         MacBook Pro  Ultrabook         Intel Core i5 3.1GHz   8GB
# ..      ...                 ...        ...                          ...   ...
# 494    Asus    Rog G752VL-UH71T     Gaming  Intel Core i7 6700HQ 2.6GHz  24GB
# 495  Lenovo       Thinkpad X260  Ultrabook   Intel Core i5 6200U 2.3GHz   8GB
# 496  Lenovo  Ideapad 520-15IKBR   Notebook   Intel Core i7 8550U 1.8GHz   8GB
# 497      HP       EliteBook 840   Notebook   Intel Core i7 7600U 2.8GHz   8GB
# 498  Lenovo         ThinkPad 13   Notebook   Intel Core i3 7100U 2.4GHz   8GB
#
# ...

# %%
data.loc[::50]
# Out:
#     Company                                Product            TypeName  \
# 0     Apple                            MacBook Pro           Ultrabook
# 50   Lenovo                              Yoga Book  2 in 1 Convertible
# 100      HP  15-bs017nv (i7-7500U/8GB/256GB/Radeon            Notebook
# 150    Dell                          Inspiron 5577              Gaming
# 200    Dell                          Inspiron 7577              Gaming
# 250    Dell                          Inspiron 5579  2 in 1 Convertible
# 300    Asus                           VivoBook S14            Notebook
# 350    Dell                                 XPS 15            Notebook
# 400  Lenovo                      IdeaPad 320-15IAP            Notebook
# 450      HP    15-bs024nv (i5-7200U/8GB/128GB/W10)            Notebook
#
#                                       Cpu   Ram                Memory  \
# 0                    Intel Core i5 2.3GHz   8GB             128GB SSD
# ...

# %%
type(data)

data[['Company', 'Product', 'Memory']].head(10)
# Out:
#   Company          Product               Memory
# 0   Apple      MacBook Pro            128GB SSD
# 1   Apple      Macbook Air  128GB Flash Storage
# 2      HP           250 G6            256GB SSD
# 3   Apple      MacBook Pro            512GB SSD
# 4   Apple      MacBook Pro            256GB SSD
# 5    Acer         Aspire 3            500GB HDD
# 6   Apple      MacBook Pro  256GB Flash Storage
# 7   Apple      Macbook Air  256GB Flash Storage
# 8    Asus  ZenBook UX430UN            512GB SSD
# 9    Acer          Swift 3            256GB SSD

# %%
plt.hist(data.Company.head(100), rwidth= 0.3)
plt.show()

# %%
labels= "data.TypeName", "data.Ram", "data.OpSys"
sizes=(20, 45, 35)

plt.pie(sizes,
       labels=labels,
       )
plt.axis('equal')
plt.show()

# %%
plt.bar(data.OpSys, data.Ram)
plt.title("bar chart")
plt.xlabel('OpSys')
plt.ylabel('Ram')
plt.show()
